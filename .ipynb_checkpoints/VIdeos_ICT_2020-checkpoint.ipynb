# %% [markdown]
# # Organização de Vídeos ICT 2019-2020

# %% [markdown]
# ## Inicialização

# %%
# Incluindo diretório scripts no caminho
from glob import glob
import sys
import os
sys.path.insert(0, './DATA/')

# %%
# show result from all calculations of the cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# pacotes básicos
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('max_colwidth',250)
import unidecode
import re

# %% [markdown]
# ## Carregando dados

# %%
colunas = ['ID', 'Título do Projeto', 'Docente', 'Centro', 'Unidade', 
           'Área Conhecimento', 'Aluno', 'CPF Aluno', 'Cota Bolsa','TIPO']

# %%
servidores = pd.read_excel('./DATA/UFCG_Servidores_Ativos.xls', converters={'CPF':str})
servidores = servidores[['CPF','Nome']]


formularios = pd.read_csv('./DATA/Formulário_ICT_VIDEOS.csv', converters={'CPF_ALUNO':str, 'CPF_ORIENTADOR':str})
formularios = formularios.dropna(axis=1, how='any')
formularios['CPF_ORIENTADOR'] = formularios['CPF_ORIENTADOR'].apply(
    lambda row: re.sub(r"\D", "", row))
formularios['CPF_ALUNO'] = formularios['CPF_ALUNO'].apply(
    lambda row: re.sub(r"\D", "", row))
formularios['TIMESTAMP'] = pd.to_datetime(formularios['TIMESTAMP'])

PIBIC = pd.read_excel('./DATA/PIBIC-2019.xls', converters={'CPF Aluno':str})
PIVIC = pd.read_excel('./DATA/PIVIC-2019.xls', converters={'CPF Aluno':str})
PIVIC_1 = pd.read_excel('./DATA/PIVIC-2019-1.xls', converters={'CPF Aluno':str})
PIBITI = pd.read_excel('./DATA/PIBITI-2019.xls', converters={'CPF Aluno':str})
PIVITI = pd.read_excel('./DATA/PIVITI-2019.xls', converters={'CPF Aluno':str})

PIBIC['TIPO'] = 'PIBIC' 
PIVIC['TIPO'] = 'PIVIC' 
PIVIC_1['TIPO'] = 'PIVIC' 
PIBITI['TIPO'] = 'PIBITI' 
PIVITI['TIPO'] = 'PIVITI' 

projetos = pd.concat([PIBIC,PIVIC,PIVIC_1, PIBITI, PIVITI])
projetos = projetos[colunas]
projetos = projetos.rename(columns={'Título do Projeto':'TITULO',
                                    'Docente':'DOCENTE',
                                    'Centro':'CENTRO',
                                    'Unidade':'UA',
                                    'Área Conhecimento':'AREA',
                                    'Aluno':'ALUNO',
                                    'CPF Aluno':'CPF_ALUNO',
                                    'Cota Bolsa':'BOLSA'})
projetos.CPF_ALUNO = projetos.CPF_ALUNO.astype(str)
projetos['DOCENTE'] = projetos['DOCENTE'].apply(
    lambda row: unidecode.unidecode(row))

dados_projetos = pd.merge(
    left=projetos, right=servidores,
    left_on='DOCENTE', right_on='Nome').drop('Nome',1)

dados_videos = pd.merge(
    left=dados_projetos, right=formularios,
    left_on='CPF_ALUNO', right_on='CPF_ALUNO')

videos = dados_videos[
    dados_videos['CPF_ORIENTADOR'] == dados_videos['CPF']
]
#Eliminando Duplicatas e ficando com a versão mais recente.
videos_validos = videos.sort_values('TIMESTAMP').drop_duplicates('CPF_ALUNO',keep='last')

#videos_validos['LINK_VIDEO']=videos_validos.apply(lambda row: row['LINK_VIDEO'].split['='][-1])


videos_validos['title'] = videos_validos.apply(lambda row: 
                     'ICT-2020-' + row['AREA'] + '-' + '-' + row['CENTRO'] +
                     '-' + row['UA'] + ':  ' + 
                     str(row['TITULO'])[0 : min(len(str(row['TITULO'])),30)] + '...',
                     axis = 1
                    )

videos_validos['description'] = 'Videos para avaliação dos projetos de Iniciação Científica e Tecnológica, vigência 2019 - 2020, da Universidade Federal de Campina Grande. Provisoriamente armazenados nesta canal por problemas técnicos.'

videos_validos['category'] = '27'

videos_validos['keywords'] = videos_validos.apply(lambda row: 
                     'UFCG,PRPG,PIBIC,PIBITI,' + row['AREA'] +',' + row['CENTRO'],
                     axis = 1
                    )

videos_validos['categorias'] = videos_validos.apply(lambda row: row['CENTRO']+'-'+row['UA'], axis = 1)

# %%
videos_validos.columns
# Out:
# Index(['ID', 'TITULO', 'DOCENTE', 'CENTRO', 'UA', 'AREA', 'ALUNO', 'CPF_ALUNO',
#        'BOLSA', 'TIPO', 'CPF', 'TIMESTAMP', 'EMAIL', 'NOME', 'CPF_ORIENTADOR',
#        'LINK_VIDEO', 'title', 'description', 'category', 'keywords',
#        'categorias'],
#       dtype='object')

# %%
videos_validos
# Out:
#        ID  \
# 46   7733
# 213  7553
# 160  7967
# 91   7811
# 106  7838
# ..    ...
# 143  8177
# 83   7793
# 73   7707
# 199  8121
# 139  7928
#
#                                                                                                                                                                                                    TITULO  \
# 46                                                            CONSUMO, DIGESTIBILIDADE E COMPORTAMENTO INGESTIVO DE CORDEIROS ALIMENTADOS COM DIETAS CONTENDO LÍQUIDO DA CASCA DA CASTANHA DE CAJU (LCC).
# 213                                                                                                               VIOLAÇÃO DA INVARIÂNCIA DE LORENTZ: DESENVOLVIMENTOS TEÓRICOS E LIMITES FENOMENOLÓGICOS
# 160  PRIVILÉGIO DE CLASSE, CONCENTRAÇÃO DE RENDA E MECANISMOS DE INDUÇÃO DAS DESIGUALDADES NO BRASIL: UMA LEITURA SOCIOLÓGICA A PARTIR DOS INSTITUTOS JURÍDICOS CONTIDOS NO SISTEMA TRIBUTÁRIO BRASILEIRO
# 91                                                                                                                                                   POESIA INFANTIL CONTEMPORÂNEA: TEMAS E PROCEDIMENTOS
# 106                                                                                       AVALIAÇÃO DOS MODELOS CLIMÁTICOS DO IPCC A PARTIR DA POSIÇÃO DA ZONA DE CONVERGÊNCIA INTERTROPICAL NO ATLÂNTICO
# ..                                                                                                                                                                                                    ...
# 143                                                                              AVALIAÇÃO DA TOXICIDADE, CITOTOXICIDADE E GENOTOXICIDADE DE ADUTOS DE MORITA-BAYLLIS-HILMAN SOBRE CÉLULAS DE ALLIUM CEPA
# 83                                                                                                                       ANATOMIA DO APARELHO REPRODUTOR DOS SAGUIS-DE-TUFOS-BRANCOS (CALLITHRIX JACCHUS)
# 73                                                                                                                                                               ANÁLISE DE ESTRUTURAS DE DADOS AVANÇADAS
# 73        27  UFCG,PRPG,PIBIC,PIBITI,CIÊNCIA DA COMPUTAÇÃO,CEEI   CEEI-UASC
# 199       27             UFCG,PRPG,PIBIC,PIBITI,ENFERMAGEM,CCBS  CCBS-UAENF
# 139       27              UFCG,PRPG,PIBIC,PIBITI,ZOOTECNIA,CSTR   CSTR-UAMV
#
# [201 rows x 21 columns]

# %%
def dict_struc(**kwargs):
      tags = None
      if kwargs['keywords']:
        tags = kwargs['keywords'].split(",")

      body=dict(
        snippet=dict(
          title=kwargs['title'],
          description=kwargs['description'],
          tags=tags,
          categoryId=kwargs['category']
        ),
        status=dict(
          privacyStatus=0
        )
      )
      return body
    
def youtube_dict(df, args):
    if bool(args):
        df = df[df['CRITERIO']==args.criteria]
    dict_list = df.apply(lambda row: dict_struc(title = row['title'], 
                                                category = row['category'],
                                                description = row['description'],
                                                keywords = row['keywords']), axis =1)
    df_out = pd.DataFrame(columns = ['ID','BODY'])
    df_out['ID'] = df['ID'].apply(lambda row: './VIDEO/' + str(row) + '.mp4')
    df_out['BODY']=dict_list
    return df_out

# %%
videos_validos.apply(lambda row: row['CENTRO']+'-'+row['UA'], axis = 1).unique().tolist()
# Out:
# ['CSTR-UAMV',
#  'CCT-UAF',
#  'CDSA-UACIS',
#  'CH-UAL',
#  'CTRN-UACA',
#  'CFP-UACEN',
#  'CEEI-UAEE',
#  'CES-UABQ',
#  'CCJS-UAD',
#  'CSTR-UACB',
#  'CCT-UAEP',
#  'CFP-UAENF',
#  'CES-UAS',
#  'CCT-UAEMAT',
#  'CCT-UAEM',
#  'CFP-UAE',
#  'CCBS-UAENF',
#  'CH-UAEDU',
#  'CTRN-UAEA',
#  'CES-UAENF',
#  'CTRN-UAEAL',
#  'CH-UAG',
#  'CTRN-UAEC',
#  'CTRN-UAMG',
#  'CCBS-UAPSI',
#  'CSTR-UAEF',
#  'CCJS-UACC',
#  'CCT-UAD',
#  'CH-UAAM',
#  'CCTA-UACTA',
#  'CDSA-UAEP',
#  'CH-UACS',
#  'CH-UAAC',
#  'CES-UAFM',
#  'CCT-UAEPETRO',
#  'CCBS-UAMED',
#  'CFP-UACS',
#  'CEEI-UASC',
#  'CCT-UAEQ',
#  'CCTA-UAGRA',
#  'CFP-ETSC',
#  'CDSA-UATEC',
#  'CFP-UACV',
#  'CFP-UAL',
#  'CCTA-DC-CCTA']

# %% [markdown]
# ## Criando Listas

# %%
listas = ['CENTRO','UA','AREA']
categorias = [videos_validos[el].unique().tolist() for el in listas]
playlists = [ videos_validos[ videos_validos[el] == categ ]['ID'] 
 for el in listas for categ in categorias[listas.index(el)] ]

# %%
column_names = ['TIPO', 'CRITERIO', 'DADOS']
df = pd.DataFrame(columns = column_names)
POS = 0
for item in listas:
    for item2 in categorias[listas.index(item)]:
        df.loc[len(df)] = [item, item2, videos_validos[videos_validos.index.isin(playlists[POS].index)]]
        POS += 1

# %%
'a' in ['a']
# Out:
# True

# %% [markdown]
# ## Teste

# %%
import videolist

# %%
listadf = videolist.do_list()
listadf
# Out:
#        ID  \
# 46   7733
# 213  7553
# 160  7967
# 91   7811
# 106  7838
# ..    ...
# 143  8177
# 83   7793
# 73   7707
# 199  8121
# 139  7928
#
#                                                                                                                                                                                                    TITULO  \
# 46                                                            CONSUMO, DIGESTIBILIDADE E COMPORTAMENTO INGESTIVO DE CORDEIROS ALIMENTADOS COM DIETAS CONTENDO LÍQUIDO DA CASCA DA CASTANHA DE CAJU (LCC).
# 213                                                                                                               VIOLAÇÃO DA INVARIÂNCIA DE LORENTZ: DESENVOLVIMENTOS TEÓRICOS E LIMITES FENOMENOLÓGICOS
# 160  PRIVILÉGIO DE CLASSE, CONCENTRAÇÃO DE RENDA E MECANISMOS DE INDUÇÃO DAS DESIGUALDADES NO BRASIL: UMA LEITURA SOCIOLÓGICA A PARTIR DOS INSTITUTOS JURÍDICOS CONTIDOS NO SISTEMA TRIBUTÁRIO BRASILEIRO
# 91                                                                                                                                                   POESIA INFANTIL CONTEMPORÂNEA: TEMAS E PROCEDIMENTOS
# 106                                                                                       AVALIAÇÃO DOS MODELOS CLIMÁTICOS DO IPCC A PARTIR DA POSIÇÃO DA ZONA DE CONVERGÊNCIA INTERTROPICAL NO ATLÂNTICO
# ..                                                                                                                                                                                                    ...
# 143                                                                              AVALIAÇÃO DA TOXICIDADE, CITOTOXICIDADE E GENOTOXICIDADE DE ADUTOS DE MORITA-BAYLLIS-HILMAN SOBRE CÉLULAS DE ALLIUM CEPA
# 83                                                                                                                       ANATOMIA DO APARELHO REPRODUTOR DOS SAGUIS-DE-TUFOS-BRANCOS (CALLITHRIX JACCHUS)
# 73                                                                                                                                                               ANÁLISE DE ESTRUTURAS DE DADOS AVANÇADAS
# 199                                                                                                   PREVALÊNCIA E INCIDÊNCIA DE LESÃO POR PRESSÃO EM PACIENTES INTERNADOS EM UNIDADES DE CLÍNICA MÉDICA
# 139                                                             DIFERENTES NÍVEIS DE ENERGIA METABOLIZÁVEL NA DIETA DE CODORNAS DE CORTE (COTURNIX COTURNIX) MACHOS CRIADAS NA REGIÃO DO SERTÃO PARAIBANO
#
#                                  DOCENTE CENTRO     UA                   AREA  \
# 46                 LEILSON ROCHA BEZERRA   CSTR   UAMV              ZOOTECNIA
# 213  EDUARDO MARCOS RODRIGUES DOS PASSOS    CCT    UAF                 FÍSICA
# 160               JOSE MARCIANO MONTEIRO   CDSA  UACIS             SOCIOLOGIA
# 91            JOSE HELDER PINHEIRO ALVES     CH    UAL                 LETRAS
# 106                     SANDRA ISAY SAAD   CTRN   UACA            GEOCIÊNCIAS
# ..                                   ...    ...    ...                    ...
# 143    GLAUCIA VERISSIMO FAHEINA MARTINS    CES    UAS           FARMACOLOGIA
# 83              GILDENOR XAVIER MEDEIROS   CSTR   UAMV             MORFOLOGIA
# 73                           ROHIT GHEYI   CEEI   UASC  CIÊNCIA DA COMPUTAÇÃO
# 91   Videos para avaliação dos projetos de Iniciação Científica e Tecnológica, vigência 2019 - 2020, da Universidade Federal de Campina Grande. Provisoriamente armazenados nesta canal por problemas técnicos.
# 106  Videos para avaliação dos projetos de Iniciação Científica e Tecnológica, vigência 2019 - 2020, da Universidade Federal de Campina Grande. Provisoriamente armazenados nesta canal por problemas técnicos.
# ..                                                                                                                                                                                                          ...
# 143  Videos para avaliação dos projetos de Iniciação Científica e Tecnológica, vigência 2019 - 2020, da Universidade Federal de Campina Grande. Provisoriamente armazenados nesta canal por problemas técnicos.
# 83   Videos para avaliação dos projetos de Iniciação Científica e Tecnológica, vigência 2019 - 2020, da Universidade Federal de Campina Grande. Provisoriamente armazenados nesta canal por problemas técnicos.
# 73   Videos para avaliação dos projetos de Iniciação Científica e Tecnológica, vigência 2019 - 2020, da Universidade Federal de Campina Grande. Provisoriamente armazenados nesta canal por problemas técnicos.
# 199  Videos para avaliação dos projetos de Iniciação Científica e Tecnológica, vigência 2019 - 2020, da Universidade Federal de Campina Grande. Provisoriamente armazenados nesta canal por problemas técnicos.
# 139  Videos para avaliação dos projetos de Iniciação Científica e Tecnológica, vigência 2019 - 2020, da Universidade Federal de Campina Grande. Provisoriamente armazenados nesta canal por problemas técnicos.
#
#     category                                           keywords
# 46        27              UFCG,PRPG,PIBIC,PIBITI,ZOOTECNIA,CSTR
# 213       27                  UFCG,PRPG,PIBIC,PIBITI,FÍSICA,CCT
# 160       27             UFCG,PRPG,PIBIC,PIBITI,SOCIOLOGIA,CDSA
# 91        27                   UFCG,PRPG,PIBIC,PIBITI,LETRAS,CH
# 106       27            UFCG,PRPG,PIBIC,PIBITI,GEOCIÊNCIAS,CTRN
# ..       ...                                                ...
# 143       27            UFCG,PRPG,PIBIC,PIBITI,FARMACOLOGIA,CES
# 83        27             UFCG,PRPG,PIBIC,PIBITI,MORFOLOGIA,CSTR
# 73        27  UFCG,PRPG,PIBIC,PIBITI,CIÊNCIA DA COMPUTAÇÃO,CEEI
# 199       27             UFCG,PRPG,PIBIC,PIBITI,ENFERMAGEM,CCBS
# 139       27              UFCG,PRPG,PIBIC,PIBITI,ZOOTECNIA,CSTR
#
# [201 rows x 20 columns]

# %%
df = videolist.do_subset(listadf)

# %%
uamv = df[df['CRITERIO']=='UAMV'].iloc[0,2]

# %%
uamv.columns
# Out:
# Index(['ID', 'TITULO', 'DOCENTE', 'CENTRO', 'UA', 'AREA', 'ALUNO', 'CPF_ALUNO',
#        'BOLSA', 'TIPO', 'CPF', 'TIMESTAMP', 'EMAIL', 'NOME', 'CPF_ORIENTADOR',
#        'LINK_VIDEO', 'title', 'description', 'category', 'keywords'],
#       dtype='object')

# %%
uamv = uamv[uamv['ID']==7733]

# %%
uamv.values[0,-5].split('=')[-1]
# Out:
# '16ubBh2OqK_dVFdRQf0rWw_49WMq2KxZp'

# %%
a = 1
a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-2953cf919041> in <module>
#       1 a = 1
# ----> 2 a = b
#
# NameError: name 'b' is not defined
